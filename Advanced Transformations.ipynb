# %%
import pandas as pd
import json

hero_powers = pd.read_csv('CSV/superhero_powers - superhero_powers.csv')

hero_info = pd.read_csv('CSV/superhero_info - superhero_info.csv')

# %%
hero_info.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}

# %%
hero_powers.head()
# Out:
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %%
hero_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Hero|Publisher  463 non-null    object
#  1   Gender          463 non-null    object
#  2   Race            463 non-null    object
#  3   Alignment       463 non-null    object
#  4   Hair color      463 non-null    object
#  5   Eye color       463 non-null    object
#  6   Skin color      463 non-null    object
#  7   Measurements    463 non-null    object
# dtypes: object(8)
# memory usage: 29.1+ KB

# %%
hero_info.duplicated().sum()
# Out:
# 0

# %%
hero_info.isna().sum()
# Out:
# Hero|Publisher    0
# Gender            0
# Race              0
# Alignment         0
# Hair color        0
# Eye color         0
# Skin color        0
# Measurements      0
# dtype: int64

# %%
hero_powers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   hero_names  667 non-null    object
#  1   Powers      667 non-null    object
# dtypes: object(2)
# memory usage: 10.5+ KB

# %%
hero_powers.duplicated().sum()
# Out:
# 0

# %%
hero_powers.isna().sum()
# Out:
# hero_names    0
# Powers        0
# dtype: int64

# %%
hero_publisher = hero_info.loc[0, "Hero|Publisher"]

print(type(hero_publisher))

hero_publisher
# Out:
# <class 'str'>
# 'A-Bomb|Marvel Comics'

# %%
measurements = hero_info.loc[0, 'Measurements']
measurements
# Out:
# "{'Height': '203.0 cm', 'Weight': '441.0 kg'}"

# %%
measurements = measurements.replace("'", '"')
measurements
# Out:
# '{"Height": "203.0 cm", "Weight": "441.0 kg"}'

# %%
fixed_measurements = json.loads(measurements)
print(type(fixed_measurements))
fixed_measurements
# Out:
# <class 'dict'>
# {'Height': '203.0 cm', 'Weight': '441.0 kg'}

# %%
hero_info['Measurements'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 463 entries, 0 to 462
# Series name: Measurements
# Non-Null Count  Dtype
# --------------  -----
# 463 non-null    object
# dtypes: object(1)
# memory usage: 3.7+ KB

# %%
hero_info['Measurements'] = hero_info['Measurements'].str.replace("'", '"')

# %%
hero_info['Measurements'] = hero_info['Measurements'].apply(json.loads)
hero_info['Measurements'].head()
# Out:
# 0    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1     {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2     {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4    {'Height': '193.0 cm', 'Weight': '122.0 kg'}
# Name: Measurements, dtype: object

# %%
test_measurement = hero_info.loc[0,'Measurements']
print(type(test_measurement))
test_measurement
# Out:
# <class 'dict'>
# {'Height': '203.0 cm', 'Weight': '441.0 kg'}

# %%
height_weight = hero_info['Measurements'].apply(pd.Series)
height_weight
# Out:
#        Height    Weight
# 0    203.0 cm  441.0 kg
# 1    191.0 cm   65.0 kg
# 2    185.0 cm   90.0 kg
# 3    203.0 cm  441.0 kg
# 4    193.0 cm  122.0 kg
# ..        ...       ...
# 458  183.0 cm   83.0 kg
# 459  165.0 cm   52.0 kg
# 460   66.0 cm   17.0 kg
# 461  170.0 cm   57.0 kg
# 462  185.0 cm   81.0 kg
#
# [463 rows x 2 columns]

# %%
hero_info = pd.concat((hero_info, height_weight), axis = 1)
hero_info.head(2)
# Out:
#                  Hero|Publisher Gender           Race Alignment Hair color  \
# 0          A-Bomb|Marvel Comics   Male          Human      good    No Hair
# 1  Abe Sapien|Dark Horse Comics   Male  Icthyo Sapien      good    No Hair
#
#   Eye color Skin color                                  Measurements  \
# 0    yellow    Unknown  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1      blue       blue   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
#
#      Height    Weight
# 0  203.0 cm  441.0 kg
# 1  191.0 cm   65.0 kg

# %%
hero_info = hero_info.drop(columns = ['Measurements'])

# %%
hero_info[['Height_cm', 'cm']] = hero_info['Height'].str.split(' ', expand = True)
hero_info.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color    Height    Weight Height_cm  cm
# 0    No Hair    yellow    Unknown  203.0 cm  441.0 kg     203.0  cm
# 1    No Hair      blue       blue  191.0 cm   65.0 kg     191.0  cm
# 2    No Hair      blue        red  185.0 cm   90.0 kg     185.0  cm
# 3    No Hair     green    Unknown  203.0 cm  441.0 kg     203.0  cm
# 4    No Hair      blue    Unknown  193.0 cm  122.0 kg     193.0  cm

# %%
hero_info[['Weight_kg', 'kg']] = hero_info['Weight'].str.split(' ', expand =True)
hero_info
# Out:
#                     Hero|Publisher  Gender               Race Alignment  \
# 0             A-Bomb|Marvel Comics    Male              Human      good
# 1     Abe Sapien|Dark Horse Comics    Male      Icthyo Sapien      good
# 2               Abin Sur|DC Comics    Male            Ungaran      good
# 3        Abomination|Marvel Comics    Male  Human / Radiation       bad
# 4      Absorbing Man|Marvel Comics    Male              Human       bad
# ..                             ...     ...                ...       ...
# 458     Yellowjacket|Marvel Comics    Male              Human      good
# 459  Yellowjacket II|Marvel Comics  Female              Human      good
# 460              Yoda|George Lucas    Male     Yoda's species      good
# 461              Zatanna|DC Comics  Female              Human      good
# 462                 Zoom|DC Comics    Male            Unknown       bad
#
#            Hair color Eye color Skin color    Height    Weight Height_cm  cm  \
# ...

# %%
hero_info = hero_info.drop(columns = ['cm', 'kg', 'Height', 'Weight'])
hero_info.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color Height_cm Weight_kg
# 0    No Hair    yellow    Unknown     203.0     441.0
# 1    No Hair      blue       blue     191.0      65.0
# 2    No Hair      blue        red     185.0      90.0
# 3    No Hair     green    Unknown     203.0     441.0
# 4    No Hair      blue    Unknown     193.0     122.0

# %%
hero_info.loc[2,'Hero|Publisher']
# Out:
# 'Abin Sur|DC Comics'

# %%
print(type(hero_powers['Powers']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
hero_info[['Hero', 'Publisher']] = hero_info['Hero|Publisher'].str.split('|',expand = True)
hero_info.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color Height_cm Weight_kg           Hero  \
# 0    No Hair    yellow    Unknown     203.0     441.0         A-Bomb
# 1    No Hair      blue       blue     191.0      65.0     Abe Sapien
# 2    No Hair      blue        red     185.0      90.0       Abin Sur
# 3    No Hair     green    Unknown     203.0     441.0    Abomination
# 4    No Hair      blue    Unknown     193.0     122.0  Absorbing Man
#
#            Publisher
# 0      Marvel Comics
# 1  Dark Horse Comics
# 2          DC Comics
# 3      Marvel Comics
# 4      Marvel Comics

# %%
hero_info = hero_info.drop(columns = ['Hero|Publisher'])
hero_info.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#   Height_cm Weight_kg           Hero          Publisher
# 0     203.0     441.0         A-Bomb      Marvel Comics
# 1     191.0      65.0     Abe Sapien  Dark Horse Comics
# 2     185.0      90.0       Abin Sur          DC Comics
# 3     203.0     441.0    Abomination      Marvel Comics
# 4     193.0     122.0  Absorbing Man      Marvel Comics

# %%
type(hero_powers['Powers'])
# Out:
# pandas.core.series.Series

# %%
hero_powers.loc[2,'Powers']
# Out:
# 'Agility,Accelerated Healing,Cold Resistance,Durability,Underwater breathing,Marksmanship,Weapons Master,Longevity,Intelligence,Super Strength,Telepathy,Stamina,Immortality,Reflexes,Enhanced Sight,Sub-Mariner'

# %%
hero_powers['temp_split'] = hero_powers['Powers'].str.split(',',expand = False)

hero_powers['temp_split']
# Out:
# 0        [Agility, Super Strength, Stamina, Super Speed]
# 1      [Accelerated Healing, Durability, Longevity, S...
# 2      [Agility, Accelerated Healing, Cold Resistance...
# 3                                   [Lantern Power Ring]
# 4      [Accelerated Healing, Intelligence, Super Stre...
#                              ...
# 662               [Flight, Energy Blasts, Size Changing]
# 663    [Cold Resistance, Durability, Longevity, Super...
# 664    [Agility, Stealth, Danger Sense, Marksmanship,...
# 665    [Cryokinesis, Telepathy, Magic, Fire Control, ...
# 666    [Super Speed, Intangibility, Time Travel, Time...
# Name: temp_split, Length: 667, dtype: object

# %%
exploded = hero_powers.explode('temp_split')

exploded
# Out:
#     hero_names                                             Powers  \
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# ..         ...                                                ...
# 665    Zatanna  Cryokinesis,Telepathy,Magic,Fire Control,Proba...
# 666       Zoom  Super Speed,Intangibility,Time Travel,Time Man...
# 666       Zoom  Super Speed,Intangibility,Time Travel,Time Man...
# 666       Zoom  Super Speed,Intangibility,Time Travel,Time Man...
# 666       Zoom  Super Speed,Intangibility,Time Travel,Time Man...
#
#               temp_split
# 0                Agility
# 0         Super Strength
# 0                Stamina
# 0            Super Speed
# 1    Accelerated Healing
# ...

# %%
cols_to_make = exploded['temp_split'].dropna().unique()

# %%
for col in cols_to_make:
    hero_powers[col] = hero_powers['Powers'].str.contains(col)
# Out:
# C:\Users\Steven (Dad)\AppData\Local\Temp\ipykernel_21384\3488520024.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   hero_powers[col] = hero_powers['Powers'].str.contains(col)
# C:\Users\Steven (Dad)\AppData\Local\Temp\ipykernel_21384\3488520024.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   hero_powers[col] = hero_powers['Powers'].str.contains(col)
# ...

# %%
hero_powers.head()
# Out:
#     hero_names                                             Powers  \
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...
#
#                                           temp_split  Agility  Super Strength  \
# 0    [Agility, Super Strength, Stamina, Super Speed]     True            True
# 1  [Accelerated Healing, Durability, Longevity, S...    False            True
# 2  [Agility, Accelerated Healing, Cold Resistance...     True            True
# 3                               [Lantern Power Ring]    False           False
# 4  [Accelerated Healing, Intelligence, Super Stre...    False            True
#
#    Stamina  Super Speed  Accelerated Healing  Durability  Longevity  ...  \
# ...

# %%
hero_powers = hero_powers.drop(columns = ['Powers', 'temp_split'])
hero_powers.head()
# Out:
#     hero_names  Agility  Super Strength  Stamina  Super Speed  \
# 0      3-D Man     True            True     True         True
# 1       A-Bomb    False            True     True        False
# 2   Abe Sapien     True            True     True        False
# 3     Abin Sur    False           False    False        False
# 4  Abomination    False            True     True         True
#
#    Accelerated Healing  Durability  Longevity  Camouflage  Self-Sustenance  \
# 0                False       False      False       False            False
# 1                 True        True       True        True             True
# 2                 True        True       True       False            False
# 3                False       False      False       False            False
# 4                 True       False      False       False            False
#
#    ...  Weather Control  Omnipresent  Omniscient  Hair Manipulation  \
# 0  ...            False        False       False              False
# ...

# %%
print(type(hero_info))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
hero_info.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#   Height_cm Weight_kg           Hero          Publisher
# 0     203.0     441.0         A-Bomb      Marvel Comics
# 1     191.0      65.0     Abe Sapien  Dark Horse Comics
# 2     185.0      90.0       Abin Sur          DC Comics
# 3     203.0     441.0    Abomination      Marvel Comics
# 4     193.0     122.0  Absorbing Man      Marvel Comics

# %%
df = pd.merge(hero_info, hero_powers, left_on = 'Hero', right_on = 'hero_names')
df
# Out:
#      Gender               Race Alignment        Hair color Eye color  \
# 0      Male              Human      good           No Hair    yellow
# 1      Male      Icthyo Sapien      good           No Hair      blue
# 2      Male            Ungaran      good           No Hair      blue
# 3      Male  Human / Radiation       bad           No Hair     green
# 4      Male              Human       bad           No Hair      blue
# ..      ...                ...       ...               ...       ...
# 458    Male              Human      good             Blond      blue
# 459  Female              Human      good  Strawberry Blond      blue
# 460    Male     Yoda's species      good             White     brown
# 461  Female              Human      good             Black      blue
# 462    Male            Unknown       bad             Brown       red
#
#     Skin color Height_cm Weight_kg             Hero          Publisher  ...  \
# ...

# %%
with_super_speed = df['Super Speed'] == True

without_super_speed = df['Super Speed'] == False
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 458    False
# 459    False
# 460     True
# 461    False
# 462     True
# Name: Super Speed, Length: 463, dtype: bool

# %%
df['Weight_kg'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 463 entries, 0 to 462
# Series name: Weight_kg
# Non-Null Count  Dtype
# --------------  -----
# 463 non-null    object
# dtypes: object(1)
# memory usage: 7.2+ KB

# %%
df['Weight_kg'] = df['Weight_kg'].astype(float)

# %%
df['Weight_kg'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 463 entries, 0 to 462
# Series name: Weight_kg
# Non-Null Count  Dtype
# --------------  -----
# 463 non-null    float64
# dtypes: float64(1)
# memory usage: 7.2 KB

# %%
df['Height_cm'] = df['Height_cm'].astype(float)

# %%
df.groupby(with_super_speed)['Weight_kg'].mean()
# Out:
# Super Speed
# False    101.773585
# True     129.404040
# Name: Weight_kg, dtype: float64

# %%
df.groupby('Publisher')['Height_cm'].mean()
# Out:
# Publisher
# DC Comics            181.923913
# Dark Horse Comics    176.909091
# George Lucas         159.600000
# Image Comics         211.000000
# Marvel Comics        191.546128
# Shueisha             171.500000
# Star Trek            181.500000
# Team Epic TV         180.750000
# Unknown              178.000000
# Name: Height_cm, dtype: float64
